# %%
import time
import re
import csv
import ast
import string
import swifter
import requests
import datetime
from tqdm import tqdm
from io import StringIO
from google_play_scraper import Sort, reviews
import pickle

import numpy as np
import pandas as pd
import plotly.graph_objects as go

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import load_model

import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Tsaqif\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tsaqif\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Prediksi Langsung

# %%
def classify_text():
    # Mapping angka ke label teks
    replace_map = {0: 'negative', 1: 'neutral', 2: 'positive'}
    
    # Ambil input teks dari user
    input_text = input("Masukkan teks yang ingin diklasifikasi: ")
    input_list = [input_text]

    # ==============================================================================
    # 1. BiLSTM Model
    # ==============================================================================
    with open('../models/tokenizer_bilstm_model_embedding.pkl', 'rb') as f:
        tokenizer = pickle.load(f)

    bilstm_model = load_model('../models/bilstm_model_embedding.keras')

    sequences = tokenizer.texts_to_sequences(input_list)
    padded_sequences = pad_sequences(sequences, maxlen=100)

    bilstm_preds = bilstm_model.predict(padded_sequences)
    bilstm_label = np.argmax(bilstm_preds, axis=1)[0]
    bilstm_label_str = replace_map[bilstm_label]

    # ==============================================================================
    # 2. Logistic Regression (CountVectorizer)
    # ==============================================================================
    with open('../models/best_pipeline_logreg_countvectorizer.pkl', 'rb') as f:
        count_model = pickle.load(f)

    count_pred = count_model.predict(input_list)[0]
    count_label_str = replace_map[count_pred]

    # ==============================================================================
    # 3. Logistic Regression (TF-IDF)
    # ==============================================================================
    with open('../models/best_pipeline_logreg_tfidf.pkl', 'rb') as f:
        tfidf_model = pickle.load(f)

    tfidf_pred = tfidf_model.predict(input_list)[0]
    tfidf_label_str = replace_map[tfidf_pred]

    # ==============================================================================
    # 4. Soft Voting Ensemble (TF-IDF)
    # ==============================================================================
    with open('../models/tfidf_vectorizer_ensamble.pkl', 'rb') as f:
        ensemble_vectorizer = pickle.load(f)

    with open('../models/soft_voting_ensamble_model_tfidf.pkl', 'rb') as f:
        ensemble_model = pickle.load(f)

    X_ensemble = ensemble_vectorizer.transform(input_list)
    ensemble_pred = ensemble_model.predict(X_ensemble)[0]
    ensemble_label_str = replace_map[ensemble_pred]

    # Cetak hasil prediksi dari semua model
    print("\nHasil Klasifikasi:")
    print(f"1. BiLSTM Model: {bilstm_label} ({bilstm_label_str})")
    print(f"2. Logistic Regression (CountVectorizer): {count_pred} ({count_label_str})")
    print(f"3. Logistic Regression (TF-IDF): {tfidf_pred} ({tfidf_label_str})")
    print(f"4. Soft Voting Ensemble: {ensemble_pred} ({ensemble_label_str})")

# %%
classify_text()
# Out:
# Masukkan teks yang ingin diklasifikasi:  Jujur saya kecewa dengan aplikasi ini, sistemnya lambat
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
#
# Hasil Klasifikasi:
# 1. BiLSTM Model: 1 (neutral)
# 2. Logistic Regression (CountVectorizer): 0 (negative)
# 3. Logistic Regression (TF-IDF): 0 (negative)
# 4. Soft Voting Ensemble: 0 (negative)

# %% [markdown]
# # Scraping

# %%
app_ids = ['com.tokopedia.tkpd']
review_data_dict = {}

for app_id in tqdm(app_ids, desc="Memproses Aplikasi"):
    try:
        review_data = []
        continuation_token = None
        matching_review_count = 0
        non_matching_review_count = 0

        # Rentang tanggal yang diinginkan (1-31 Desember 2024)
        end_date = datetime.datetime(2024, 12, 31, 23, 59, 59)
        start_date = datetime.datetime(2024, 12, 1, 0, 0, 0)

        review_bar = tqdm(desc=f'Ulasan untuk {app_id}: ', total=500)
        while True:
            review_result, continuation_token = reviews(
                app_id,
                lang='id',              # Bahasa Indonesia
                country='id',           # Negara Indonesia
                sort=Sort.NEWEST,       # Urutkan dari yang terbaru
                count=100,              # Ambil 100 ulasan per batch
                continuation_token=continuation_token
            )

            filtered_reviews = [review for review in review_result if start_date <= review['at'] <= end_date]
            review_data.extend(filtered_reviews)

            for review in review_result:
                if review['at'] < start_date:
                    non_matching_review_count += 1
                elif start_date <= review['at'] <= end_date:
                    matching_review_count += 1
                    non_matching_review_count = 0
                else:
                    non_matching_review_count = 0

            review_bar.update(1)
            review_bar.set_postfix({
                'Cocok': matching_review_count,
                'Tidak Cocok': non_matching_review_count
            })

            if not continuation_token or non_matching_review_count >= 500:
                break

        review_bar.close()

        kolom_data = ['reviewId', 'userName', 'content', 'score', 'thumbsUpCount', 'at', 'reviewCreatedVersion', 'appVersion']
        review_data_dict[app_id] = pd.DataFrame(review_data, columns=kolom_data)

        time.sleep(5)

    except Exception as e:
        print(f'Error saat mengambil ulasan untuk aplikasi {app_id}: {e}')
# Out:
# Memproses Aplikasi:   0%|          | 0/1 [00:00<?, ?it/s]
# Ulasan untuk com.tokopedia.tkpd:   0%|          | 0/500 [00:00<?, ?it/s]
# Ulasan untuk com.tokopedia.tkpd:   0%|          | 1/500 [00:00<01:12,  6.88it/s]
# Ulasan untuk com.tokopedia.tkpd:   0%|          | 1/500 [00:00<01:12,  6.88it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   0%|          | 2/500 [00:00<01:23,  5.94it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   0%|          | 2/500 [00:00<01:23,  5.94it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|          | 3/500 [00:00<01:16,  6.50it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|          | 3/500 [00:00<01:16,  6.50it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|          | 4/500 [00:00<01:12,  6.82it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|          | 4/500 [00:00<01:12,  6.82it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|          | 5/500 [00:00<01:12,  6.82it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|          | 5/500 [00:00<01:12,  6.82it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|          | 6/500 [00:00<01:14,  6.65it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|          | 6/500 [00:00<01:14,  6.65it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|▏         | 7/500 [00:01<01:15,  6.56it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   1%|▏         | 7/500 [00:01<01:15,  6.56it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 8/500 [00:01<01:15,  6.54it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 8/500 [00:01<01:15,  6.54it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 9/500 [00:01<01:12,  6.78it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 9/500 [00:01<01:12,  6.78it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 10/500 [00:01<01:11,  6.81it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 10/500 [00:01<01:11,  6.81it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 11/500 [00:01<01:11,  6.87it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 11/500 [00:01<01:11,  6.87it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 12/500 [00:01<01:12,  6.76it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   2%|▏         | 12/500 [00:01<01:12,  6.76it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 13/500 [00:01<01:11,  6.85it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 13/500 [00:01<01:11,  6.85it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 14/500 [00:02<01:09,  7.02it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 14/500 [00:02<01:09,  7.02it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 15/500 [00:02<01:11,  6.78it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 15/500 [00:02<01:11,  6.78it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 16/500 [00:02<01:08,  7.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 16/500 [00:02<01:08,  7.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 17/500 [00:02<01:09,  6.95it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   3%|▎         | 17/500 [00:02<01:09,  6.95it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▎         | 18/500 [00:02<01:10,  6.84it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▎         | 18/500 [00:02<01:10,  6.84it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▍         | 19/500 [00:02<01:11,  6.77it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▍         | 19/500 [00:02<01:11,  6.77it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▍         | 20/500 [00:02<01:09,  6.92it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▍         | 20/500 [00:02<01:09,  6.92it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▍         | 21/500 [00:03<01:14,  6.43it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▍         | 21/500 [00:03<01:14,  6.43it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▍         | 22/500 [00:03<01:11,  6.68it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   4%|▍         | 22/500 [00:03<01:11,  6.68it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▍         | 23/500 [00:03<01:09,  6.82it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▍         | 23/500 [00:03<01:09,  6.82it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▍         | 24/500 [00:03<01:11,  6.66it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▍         | 24/500 [00:03<01:11,  6.66it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▌         | 25/500 [00:03<01:12,  6.58it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▌         | 25/500 [00:03<01:12,  6.58it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▌         | 26/500 [00:03<01:13,  6.47it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▌         | 26/500 [00:03<01:13,  6.47it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▌         | 27/500 [00:04<01:10,  6.67it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   5%|▌         | 27/500 [00:04<01:10,  6.67it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▌         | 28/500 [00:04<01:14,  6.35it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▌         | 28/500 [00:04<01:14,  6.35it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▌         | 29/500 [00:04<01:14,  6.29it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▌         | 29/500 [00:04<01:14,  6.29it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▌         | 30/500 [00:04<01:14,  6.28it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▌         | 30/500 [00:04<01:14,  6.28it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▌         | 31/500 [00:04<01:12,  6.44it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▌         | 31/500 [00:04<01:12,  6.44it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▋         | 32/500 [00:04<01:13,  6.38it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   6%|▋         | 32/500 [00:04<01:13,  6.38it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 33/500 [00:05<01:16,  6.07it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 33/500 [00:05<01:16,  6.07it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 34/500 [00:05<01:18,  5.92it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 34/500 [00:05<01:18,  5.92it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 35/500 [00:05<01:19,  5.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 35/500 [00:05<01:19,  5.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 36/500 [00:05<01:17,  5.96it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 36/500 [00:05<01:17,  5.96it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 37/500 [00:05<01:18,  5.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   7%|▋         | 37/500 [00:05<01:18,  5.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 38/500 [00:05<01:19,  5.78it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 38/500 [00:05<01:19,  5.78it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 39/500 [00:06<01:22,  5.59it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 39/500 [00:06<01:22,  5.59it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 40/500 [00:06<01:20,  5.71it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 40/500 [00:06<01:20,  5.71it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 41/500 [00:06<01:21,  5.64it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 41/500 [00:06<01:21,  5.64it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 42/500 [00:06<01:23,  5.51it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   8%|▊         | 42/500 [00:06<01:23,  5.51it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▊         | 43/500 [00:06<01:19,  5.72it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▊         | 43/500 [00:06<01:19,  5.72it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▉         | 44/500 [00:06<01:18,  5.79it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▉         | 44/500 [00:06<01:18,  5.79it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▉         | 45/500 [00:07<01:19,  5.70it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▉         | 45/500 [00:07<01:19,  5.70it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▉         | 46/500 [00:07<01:23,  5.40it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▉         | 46/500 [00:07<01:23,  5.40it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▉         | 47/500 [00:07<01:27,  5.17it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:   9%|▉         | 47/500 [00:07<01:27,  5.17it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|▉         | 48/500 [00:07<01:27,  5.14it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|▉         | 48/500 [00:07<01:27,  5.14it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|▉         | 49/500 [00:07<01:29,  5.07it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|▉         | 49/500 [00:07<01:29,  5.07it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|█         | 50/500 [00:08<01:29,  5.01it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|█         | 50/500 [00:08<01:29,  5.01it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|█         | 51/500 [00:08<01:33,  4.82it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|█         | 51/500 [00:08<01:33,  4.82it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|█         | 52/500 [00:08<01:39,  4.49it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  10%|█         | 52/500 [00:08<01:39,  4.49it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█         | 53/500 [00:08<01:40,  4.43it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█         | 53/500 [00:08<01:40,  4.43it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█         | 54/500 [00:09<01:37,  4.59it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█         | 54/500 [00:09<01:37,  4.59it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█         | 55/500 [00:09<01:31,  4.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█         | 55/500 [00:09<01:31,  4.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█         | 56/500 [00:09<01:31,  4.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█         | 56/500 [00:09<01:31,  4.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█▏        | 57/500 [00:09<01:26,  5.09it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  11%|█▏        | 57/500 [00:09<01:26,  5.09it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 58/500 [00:09<01:27,  5.08it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 58/500 [00:09<01:27,  5.08it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 59/500 [00:10<01:25,  5.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 59/500 [00:10<01:25,  5.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 60/500 [00:10<01:24,  5.23it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 60/500 [00:10<01:24,  5.23it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 61/500 [00:10<01:24,  5.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 61/500 [00:10<01:24,  5.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 62/500 [00:10<01:24,  5.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  12%|█▏        | 62/500 [00:10<01:24,  5.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 63/500 [00:10<01:26,  5.06it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 63/500 [00:10<01:26,  5.06it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 64/500 [00:10<01:26,  5.05it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 64/500 [00:10<01:26,  5.05it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 65/500 [00:11<01:24,  5.13it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 65/500 [00:11<01:24,  5.13it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 66/500 [00:11<01:24,  5.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 66/500 [00:11<01:24,  5.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 67/500 [00:11<01:23,  5.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  13%|█▎        | 67/500 [00:11<01:23,  5.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▎        | 68/500 [00:11<01:23,  5.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▎        | 68/500 [00:11<01:23,  5.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▍        | 69/500 [00:11<01:23,  5.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▍        | 69/500 [00:11<01:23,  5.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▍        | 70/500 [00:12<01:22,  5.19it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▍        | 70/500 [00:12<01:22,  5.19it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▍        | 71/500 [00:12<01:25,  5.01it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▍        | 71/500 [00:12<01:25,  5.01it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▍        | 72/500 [00:12<01:25,  4.99it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  14%|█▍        | 72/500 [00:12<01:25,  4.99it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▍        | 73/500 [00:12<01:23,  5.09it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▍        | 73/500 [00:12<01:23,  5.09it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▍        | 74/500 [00:12<01:27,  4.87it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▍        | 74/500 [00:12<01:27,  4.87it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▌        | 75/500 [00:13<01:29,  4.77it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▌        | 75/500 [00:13<01:29,  4.77it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▌        | 76/500 [00:13<01:39,  4.25it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▌        | 76/500 [00:13<01:39,  4.25it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▌        | 77/500 [00:13<01:37,  4.36it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  15%|█▌        | 77/500 [00:13<01:37,  4.36it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▌        | 78/500 [00:13<01:34,  4.46it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▌        | 78/500 [00:13<01:34,  4.46it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▌        | 79/500 [00:14<01:36,  4.34it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▌        | 79/500 [00:14<01:36,  4.34it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▌        | 80/500 [00:14<01:37,  4.30it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▌        | 80/500 [00:14<01:37,  4.30it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▌        | 81/500 [00:14<01:33,  4.47it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▌        | 81/500 [00:14<01:33,  4.47it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▋        | 82/500 [00:14<01:29,  4.65it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  16%|█▋        | 82/500 [00:14<01:29,  4.65it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 83/500 [00:14<01:29,  4.68it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 83/500 [00:15<01:29,  4.68it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 84/500 [00:15<01:36,  4.30it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 84/500 [00:15<01:36,  4.30it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 85/500 [00:15<01:31,  4.52it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 85/500 [00:15<01:31,  4.52it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 86/500 [00:16<03:12,  2.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 86/500 [00:16<03:12,  2.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 87/500 [00:16<02:48,  2.45it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  17%|█▋        | 87/500 [00:16<02:48,  2.45it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 88/500 [00:16<02:22,  2.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 88/500 [00:16<02:22,  2.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 89/500 [00:17<02:05,  3.28it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 89/500 [00:17<02:05,  3.28it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 90/500 [00:17<01:53,  3.62it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 90/500 [00:17<01:53,  3.62it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 91/500 [00:17<01:47,  3.80it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 91/500 [00:17<01:47,  3.80it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 92/500 [00:17<01:44,  3.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  18%|█▊        | 92/500 [00:17<01:44,  3.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▊        | 93/500 [00:18<01:43,  3.95it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▊        | 93/500 [00:18<01:43,  3.95it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▉        | 94/500 [00:18<01:40,  4.05it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▉        | 94/500 [00:18<01:40,  4.05it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▉        | 95/500 [00:18<01:38,  4.09it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▉        | 95/500 [00:18<01:38,  4.09it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▉        | 96/500 [00:18<01:35,  4.22it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▉        | 96/500 [00:18<01:35,  4.22it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▉        | 97/500 [00:19<01:36,  4.18it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  19%|█▉        | 97/500 [00:19<01:36,  4.18it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|█▉        | 98/500 [00:19<01:33,  4.31it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|█▉        | 98/500 [00:19<01:33,  4.31it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|█▉        | 99/500 [00:19<01:35,  4.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|█▉        | 99/500 [00:19<01:35,  4.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|██        | 100/500 [00:19<01:35,  4.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|██        | 100/500 [00:19<01:35,  4.20it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|██        | 101/500 [00:20<01:36,  4.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|██        | 101/500 [00:20<01:36,  4.15it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|██        | 102/500 [00:20<01:32,  4.29it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  20%|██        | 102/500 [00:20<01:32,  4.29it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██        | 103/500 [00:20<01:31,  4.34it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██        | 103/500 [00:20<01:31,  4.34it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██        | 104/500 [00:20<01:31,  4.32it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██        | 104/500 [00:20<01:31,  4.32it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██        | 105/500 [00:20<01:35,  4.16it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██        | 105/500 [00:20<01:35,  4.16it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██        | 106/500 [00:21<01:37,  4.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██        | 106/500 [00:21<01:37,  4.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██▏       | 107/500 [00:21<01:37,  4.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  21%|██▏       | 107/500 [00:21<01:37,  4.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 108/500 [00:21<01:40,  3.91it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 108/500 [00:21<01:40,  3.91it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 109/500 [00:21<01:38,  3.97it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 109/500 [00:21<01:38,  3.97it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 110/500 [00:22<01:40,  3.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 110/500 [00:22<01:40,  3.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 111/500 [00:22<01:37,  3.99it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 111/500 [00:22<01:37,  3.99it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 112/500 [00:22<01:36,  4.00it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  22%|██▏       | 112/500 [00:22<01:36,  4.00it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 113/500 [00:22<01:35,  4.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 113/500 [00:22<01:35,  4.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 114/500 [00:23<01:37,  3.96it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 114/500 [00:23<01:37,  3.96it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 115/500 [00:23<01:35,  4.02it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 115/500 [00:23<01:35,  4.02it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 116/500 [00:23<01:35,  4.01it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 116/500 [00:23<01:35,  4.01it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 117/500 [00:23<01:33,  4.09it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  23%|██▎       | 117/500 [00:23<01:33,  4.09it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▎       | 118/500 [00:24<01:38,  3.88it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▎       | 118/500 [00:24<01:38,  3.88it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▍       | 119/500 [00:24<01:37,  3.90it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▍       | 119/500 [00:24<01:37,  3.90it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▍       | 120/500 [00:24<01:36,  3.92it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▍       | 120/500 [00:24<01:36,  3.92it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▍       | 121/500 [00:25<01:41,  3.73it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▍       | 121/500 [00:25<01:41,  3.73it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▍       | 122/500 [00:25<01:43,  3.66it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  24%|██▍       | 122/500 [00:25<01:43,  3.66it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▍       | 123/500 [00:25<01:40,  3.75it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▍       | 123/500 [00:25<01:40,  3.75it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▍       | 124/500 [00:25<01:37,  3.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▍       | 124/500 [00:25<01:37,  3.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▌       | 125/500 [00:26<01:39,  3.78it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▌       | 125/500 [00:26<01:39,  3.78it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▌       | 126/500 [00:26<01:36,  3.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▌       | 126/500 [00:26<01:36,  3.89it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▌       | 127/500 [00:26<01:33,  3.98it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  25%|██▌       | 127/500 [00:26<01:33,  3.98it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▌       | 128/500 [00:26<01:32,  4.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▌       | 128/500 [00:26<01:32,  4.03it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▌       | 129/500 [00:27<01:32,  4.01it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▌       | 129/500 [00:27<01:32,  4.01it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▌       | 130/500 [00:27<01:47,  3.45it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▌       | 130/500 [00:27<01:47,  3.45it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▌       | 131/500 [00:27<01:43,  3.56it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▌       | 131/500 [00:27<01:43,  3.56it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▋       | 132/500 [00:27<01:42,  3.57it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  26%|██▋       | 132/500 [00:27<01:42,  3.57it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 133/500 [00:28<01:44,  3.52it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 133/500 [00:28<01:44,  3.52it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 134/500 [00:28<01:41,  3.60it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 134/500 [00:28<01:41,  3.60it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 135/500 [00:28<01:41,  3.58it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 135/500 [00:28<01:41,  3.58it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 136/500 [00:29<01:41,  3.60it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 136/500 [00:29<01:41,  3.60it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 137/500 [00:29<01:41,  3.57it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  27%|██▋       | 137/500 [00:29<01:41,  3.57it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 138/500 [00:29<01:39,  3.63it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 138/500 [00:29<01:39,  3.63it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 139/500 [00:29<01:39,  3.62it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 139/500 [00:29<01:39,  3.62it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 140/500 [00:30<01:39,  3.60it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 140/500 [00:30<01:39,  3.60it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 141/500 [00:30<01:37,  3.69it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 141/500 [00:30<01:37,  3.69it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 142/500 [00:30<01:34,  3.77it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  28%|██▊       | 142/500 [00:30<01:34,  3.77it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▊       | 143/500 [00:30<01:32,  3.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▊       | 143/500 [00:30<01:32,  3.86it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▉       | 144/500 [00:31<01:35,  3.72it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▉       | 144/500 [00:31<01:35,  3.72it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▉       | 145/500 [00:31<01:36,  3.67it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▉       | 145/500 [00:31<01:36,  3.67it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▉       | 146/500 [00:31<01:36,  3.68it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▉       | 146/500 [00:31<01:36,  3.68it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▉       | 147/500 [00:32<01:35,  3.68it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  29%|██▉       | 147/500 [00:32<01:35,  3.68it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|██▉       | 148/500 [00:32<01:37,  3.61it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|██▉       | 148/500 [00:32<01:37,  3.61it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|██▉       | 149/500 [00:32<01:33,  3.76it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|██▉       | 149/500 [00:32<01:33,  3.76it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|███       | 150/500 [00:32<01:34,  3.69it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|███       | 150/500 [00:32<01:34,  3.69it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|███       | 151/500 [00:33<01:37,  3.59it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|███       | 151/500 [00:33<01:37,  3.59it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|███       | 152/500 [00:33<01:36,  3.60it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  30%|███       | 152/500 [00:33<01:36,  3.60it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███       | 153/500 [00:33<01:39,  3.50it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███       | 153/500 [00:33<01:39,  3.50it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███       | 154/500 [00:34<01:36,  3.57it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███       | 154/500 [00:34<01:36,  3.57it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███       | 155/500 [00:34<01:42,  3.35it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███       | 155/500 [00:34<01:42,  3.35it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███       | 156/500 [00:34<01:43,  3.31it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███       | 156/500 [00:34<01:43,  3.31it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███▏      | 157/500 [00:34<01:39,  3.44it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  31%|███▏      | 157/500 [00:34<01:39,  3.44it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 158/500 [00:35<01:35,  3.58it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 158/500 [00:35<01:35,  3.58it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 159/500 [00:35<01:37,  3.51it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 159/500 [00:35<01:37,  3.51it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 160/500 [00:35<01:37,  3.50it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 160/500 [00:35<01:37,  3.50it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 161/500 [00:36<01:37,  3.49it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 161/500 [00:36<01:37,  3.49it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 162/500 [00:36<01:35,  3.55it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  32%|███▏      | 162/500 [00:36<01:35,  3.55it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 163/500 [00:36<01:35,  3.52it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 163/500 [00:36<01:35,  3.52it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 164/500 [00:36<01:37,  3.46it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 164/500 [00:36<01:37,  3.46it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 165/500 [00:37<01:37,  3.43it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 165/500 [00:37<01:37,  3.43it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 166/500 [00:37<01:35,  3.50it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 166/500 [00:37<01:35,  3.50it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 167/500 [00:37<01:35,  3.48it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  33%|███▎      | 167/500 [00:37<01:35,  3.48it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▎      | 168/500 [00:38<01:35,  3.47it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▎      | 168/500 [00:38<01:35,  3.47it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▍      | 169/500 [00:38<01:37,  3.40it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▍      | 169/500 [00:38<01:37,  3.40it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▍      | 170/500 [00:38<01:36,  3.41it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▍      | 170/500 [00:38<01:36,  3.41it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▍      | 171/500 [00:38<01:37,  3.39it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▍      | 171/500 [00:38<01:37,  3.39it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▍      | 172/500 [00:39<01:37,  3.37it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  34%|███▍      | 172/500 [00:39<01:37,  3.37it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▍      | 173/500 [00:39<01:38,  3.33it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▍      | 173/500 [00:39<01:38,  3.33it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▍      | 174/500 [00:39<01:37,  3.35it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▍      | 174/500 [00:39<01:37,  3.35it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▌      | 175/500 [00:40<01:36,  3.35it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▌      | 175/500 [00:40<01:36,  3.35it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▌      | 176/500 [00:40<01:35,  3.40it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▌      | 176/500 [00:40<01:35,  3.40it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▌      | 177/500 [00:40<01:35,  3.37it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  35%|███▌      | 177/500 [00:40<01:35,  3.37it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▌      | 178/500 [00:41<01:33,  3.44it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▌      | 178/500 [00:41<01:33,  3.44it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▌      | 179/500 [00:41<01:36,  3.34it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▌      | 179/500 [00:41<01:36,  3.34it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▌      | 180/500 [00:41<01:38,  3.24it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▌      | 180/500 [00:41<01:38,  3.24it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▌      | 181/500 [00:42<01:38,  3.23it/s, Cocok=0, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▌      | 181/500 [00:42<01:38,  3.23it/s, Cocok=68, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▋      | 182/500 [00:42<01:40,  3.16it/s, Cocok=68, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  36%|███▋      | 182/500 [00:42<01:40,  3.16it/s, Cocok=168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 183/500 [00:42<01:44,  3.04it/s, Cocok=168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 183/500 [00:42<01:44,  3.04it/s, Cocok=268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 184/500 [00:43<01:41,  3.11it/s, Cocok=268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 184/500 [00:43<01:41,  3.11it/s, Cocok=368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 185/500 [00:43<01:41,  3.11it/s, Cocok=368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 185/500 [00:43<01:41,  3.11it/s, Cocok=468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 186/500 [00:43<01:40,  3.14it/s, Cocok=468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 186/500 [00:43<01:40,  3.14it/s, Cocok=568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 187/500 [00:44<01:45,  2.97it/s, Cocok=568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  37%|███▋      | 187/500 [00:44<01:45,  2.97it/s, Cocok=668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 188/500 [00:44<01:44,  2.99it/s, Cocok=668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 188/500 [00:44<01:44,  2.99it/s, Cocok=768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 189/500 [00:44<01:42,  3.02it/s, Cocok=768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 189/500 [00:44<01:42,  3.02it/s, Cocok=868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 190/500 [00:44<01:37,  3.18it/s, Cocok=868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 190/500 [00:44<01:37,  3.18it/s, Cocok=968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 191/500 [00:45<01:36,  3.19it/s, Cocok=968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 191/500 [00:45<01:36,  3.19it/s, Cocok=1068, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 192/500 [00:45<01:32,  3.35it/s, Cocok=1068, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  38%|███▊      | 192/500 [00:45<01:32,  3.35it/s, Cocok=1168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▊      | 193/500 [00:45<01:33,  3.29it/s, Cocok=1168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▊      | 193/500 [00:45<01:33,  3.29it/s, Cocok=1268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▉      | 194/500 [00:46<01:31,  3.34it/s, Cocok=1268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▉      | 194/500 [00:46<01:31,  3.34it/s, Cocok=1368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▉      | 195/500 [00:46<01:34,  3.22it/s, Cocok=1368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▉      | 195/500 [00:46<01:34,  3.22it/s, Cocok=1468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▉      | 196/500 [00:46<01:34,  3.21it/s, Cocok=1468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▉      | 196/500 [00:46<01:34,  3.21it/s, Cocok=1568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▉      | 197/500 [00:47<01:39,  3.04it/s, Cocok=1568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  39%|███▉      | 197/500 [00:47<01:39,  3.04it/s, Cocok=1668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|███▉      | 198/500 [00:47<01:37,  3.10it/s, Cocok=1668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|███▉      | 198/500 [00:47<01:37,  3.10it/s, Cocok=1768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|███▉      | 199/500 [00:47<01:41,  2.96it/s, Cocok=1768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|███▉      | 199/500 [00:47<01:41,  2.96it/s, Cocok=1868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|████      | 200/500 [00:48<01:37,  3.09it/s, Cocok=1868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|████      | 200/500 [00:48<01:37,  3.09it/s, Cocok=1968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|████      | 201/500 [00:48<01:36,  3.10it/s, Cocok=1968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|████      | 201/500 [00:48<01:36,  3.10it/s, Cocok=2068, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|████      | 202/500 [00:48<01:37,  3.07it/s, Cocok=2068, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  40%|████      | 202/500 [00:48<01:37,  3.07it/s, Cocok=2168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████      | 203/500 [00:49<01:32,  3.21it/s, Cocok=2168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████      | 203/500 [00:49<01:32,  3.21it/s, Cocok=2268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████      | 204/500 [00:49<01:34,  3.14it/s, Cocok=2268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████      | 204/500 [00:49<01:34,  3.14it/s, Cocok=2368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████      | 205/500 [00:49<01:32,  3.18it/s, Cocok=2368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████      | 205/500 [00:49<01:32,  3.18it/s, Cocok=2468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████      | 206/500 [00:50<01:36,  3.06it/s, Cocok=2468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████      | 206/500 [00:50<01:36,  3.06it/s, Cocok=2568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████▏     | 207/500 [00:50<01:36,  3.04it/s, Cocok=2568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  41%|████▏     | 207/500 [00:50<01:36,  3.04it/s, Cocok=2668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 208/500 [00:50<01:34,  3.08it/s, Cocok=2668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 208/500 [00:50<01:34,  3.08it/s, Cocok=2768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 209/500 [00:51<01:36,  3.02it/s, Cocok=2768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 209/500 [00:51<01:36,  3.02it/s, Cocok=2868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 210/500 [00:51<01:32,  3.13it/s, Cocok=2868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 210/500 [00:51<01:32,  3.13it/s, Cocok=2968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 211/500 [00:51<01:31,  3.17it/s, Cocok=2968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 211/500 [00:51<01:31,  3.17it/s, Cocok=3068, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 212/500 [00:51<01:31,  3.15it/s, Cocok=3068, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  42%|████▏     | 212/500 [00:51<01:31,  3.15it/s, Cocok=3168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 213/500 [00:52<01:34,  3.05it/s, Cocok=3168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 213/500 [00:52<01:34,  3.05it/s, Cocok=3268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 214/500 [00:52<01:32,  3.09it/s, Cocok=3268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 214/500 [00:52<01:32,  3.09it/s, Cocok=3368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 215/500 [00:52<01:30,  3.15it/s, Cocok=3368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 215/500 [00:52<01:30,  3.15it/s, Cocok=3468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 216/500 [00:53<01:34,  3.00it/s, Cocok=3468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 216/500 [00:53<01:34,  3.00it/s, Cocok=3568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 217/500 [00:53<01:37,  2.89it/s, Cocok=3568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  43%|████▎     | 217/500 [00:53<01:37,  2.89it/s, Cocok=3668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▎     | 218/500 [00:54<01:37,  2.89it/s, Cocok=3668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▎     | 218/500 [00:54<01:37,  2.89it/s, Cocok=3768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▍     | 219/500 [00:54<01:35,  2.96it/s, Cocok=3768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▍     | 219/500 [00:54<01:35,  2.96it/s, Cocok=3868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▍     | 220/500 [00:54<01:34,  2.97it/s, Cocok=3868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▍     | 220/500 [00:54<01:34,  2.97it/s, Cocok=3968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▍     | 221/500 [00:55<01:33,  2.97it/s, Cocok=3968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▍     | 221/500 [00:55<01:33,  2.97it/s, Cocok=4068, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▍     | 222/500 [00:55<01:31,  3.04it/s, Cocok=4068, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  44%|████▍     | 222/500 [00:55<01:31,  3.04it/s, Cocok=4168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▍     | 223/500 [00:55<01:31,  3.04it/s, Cocok=4168, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▍     | 223/500 [00:55<01:31,  3.04it/s, Cocok=4268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▍     | 224/500 [00:56<01:34,  2.91it/s, Cocok=4268, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▍     | 224/500 [00:56<01:34,  2.91it/s, Cocok=4368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▌     | 225/500 [00:56<01:34,  2.92it/s, Cocok=4368, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▌     | 225/500 [00:56<01:34,  2.92it/s, Cocok=4468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▌     | 226/500 [00:56<01:37,  2.82it/s, Cocok=4468, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▌     | 226/500 [00:56<01:37,  2.82it/s, Cocok=4568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▌     | 227/500 [00:57<01:36,  2.84it/s, Cocok=4568, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  45%|████▌     | 227/500 [00:57<01:36,  2.84it/s, Cocok=4668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▌     | 228/500 [00:57<01:36,  2.83it/s, Cocok=4668, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▌     | 228/500 [00:57<01:36,  2.83it/s, Cocok=4768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▌     | 229/500 [00:57<01:36,  2.80it/s, Cocok=4768, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▌     | 229/500 [00:57<01:36,  2.80it/s, Cocok=4868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▌     | 230/500 [00:58<01:40,  2.69it/s, Cocok=4868, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▌     | 230/500 [00:58<01:40,  2.69it/s, Cocok=4968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▌     | 231/500 [00:58<01:41,  2.64it/s, Cocok=4968, Tidak Cocok=0]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▌     | 231/500 [00:58<01:41,  2.64it/s, Cocok=5055, Tidak Cocok=13]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▋     | 232/500 [00:58<01:39,  2.68it/s, Cocok=5055, Tidak Cocok=13]
# Ulasan untuk com.tokopedia.tkpd:  46%|████▋     | 232/500 [00:58<01:39,  2.68it/s, Cocok=5055, Tidak Cocok=113]
# Ulasan untuk com.tokopedia.tkpd:  47%|████▋     | 233/500 [00:59<01:35,  2.78it/s, Cocok=5055, Tidak Cocok=113]
# Ulasan untuk com.tokopedia.tkpd:  47%|████▋     | 233/500 [00:59<01:35,  2.78it/s, Cocok=5055, Tidak Cocok=213]
# Ulasan untuk com.tokopedia.tkpd:  47%|████▋     | 234/500 [00:59<01:38,  2.71it/s, Cocok=5055, Tidak Cocok=213]
# Ulasan untuk com.tokopedia.tkpd:  47%|████▋     | 234/500 [00:59<01:38,  2.71it/s, Cocok=5055, Tidak Cocok=313]
# Ulasan untuk com.tokopedia.tkpd:  47%|████▋     | 235/500 [01:00<01:36,  2.74it/s, Cocok=5055, Tidak Cocok=313]
# Ulasan untuk com.tokopedia.tkpd:  47%|████▋     | 235/500 [01:00<01:36,  2.74it/s, Cocok=5055, Tidak Cocok=413]
# Ulasan untuk com.tokopedia.tkpd:  47%|████▋     | 236/500 [01:00<01:37,  2.70it/s, Cocok=5055, Tidak Cocok=413]
# Ulasan untuk com.tokopedia.tkpd:  47%|████▋     | 236/500 [01:00<01:07,  3.90it/s, Cocok=5055, Tidak Cocok=513]
# Memproses Aplikasi: 100%|██████████| 1/1 [01:05<00:00, 65.48s/it]

# %%
df = review_data_dict['com.tokopedia.tkpd'].head()
print(df.shape)
df.head()
# Out:
# (5, 8)
#                                reviewId      userName  \
# 0  3423f5d8-b98e-4cd3-b6dd-c8f1d6f87383   Reza Bolang
# 1  e01983cf-38c5-4dda-86ef-7cfe75959977      bram bey
# 2  b45c0a9a-3fb2-439b-92d2-bf64e03fa7ce   I—YOUNG LEX
# 3  26529007-ea7e-4e33-ab5e-18e75504465b   Windi Maura
# 4  4c1bef94-b634-48c1-a86b-eb25ce5dbf6a  Atik Sumarti
#
#                                              content  score  thumbsUpCount  \
# 0  Gara aplikasi ini WhatsApp gw gk bsa di buka 😡...      1              0
# 1                                   Terimakasih.....      5              0
# 2                                       sangat cocok      5              0
# 3  jujur saya kecewa dg apk ini,bagian alamat tdk...      2              0
# 4  Sangat kecewa dengan sistem Tokopedia order ba...      2              3
#
#                    at reviewCreatedVersion appVersion
# 0 2024-12-31 23:52:31              3.293.1    3.293.1
# 1 2024-12-31 23:51:20              3.294.1    3.294.1
# 2 2024-12-31 23:42:18              3.289.0    3.289.0
# 3 2024-12-31 23:17:47                 None       None
# 4 2024-12-31 23:14:02              3.294.1    3.294.1

# %% [markdown]
# # Predict

# %%
df_selected = df[['content']]
df_selected.rename(columns={'content': 'reprocessed_content'}, inplace=True)
df_selected
# Out:
# <ipython-input-73-de84bd821c9b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.rename(columns={'content': 'reprocessed_content'}, inplace=True)
#                                  reprocessed_content
# 0  Gara aplikasi ini WhatsApp gw gk bsa di buka 😡...
# 1                                   Terimakasih.....
# 2                                       sangat cocok
# 3  jujur saya kecewa dg apk ini,bagian alamat tdk...
# 4  Sangat kecewa dengan sistem Tokopedia order ba...

# %%
# ==============================================================================
# 1. BiLSTM Model
# ==============================================================================
with open('../models/tokenizer_bilstm_model_embedding.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

bilstm_model = load_model('../models/bilstm_model_embedding.keras')

sequences = tokenizer.texts_to_sequences(df_selected['reprocessed_content'])
padded_sequences = pad_sequences(sequences, maxlen=100)

bilstm_preds = bilstm_model.predict(padded_sequences)
bilstm_labels = np.argmax(bilstm_preds, axis=1)

# ==============================================================================
# 2. Logistic Regression (CountVectorizer)
# ==============================================================================
with open('../models/best_pipeline_logreg_countvectorizer.pkl', 'rb') as f:
    count_model = pickle.load(f)

count_preds = count_model.predict(df_selected['reprocessed_content'])

# ==============================================================================
# 3. Logistic Regression (TF-IDF)
with open('../models/best_pipeline_logreg_tfidf.pkl', 'rb') as f:
    tfidf_model = pickle.load(f)

tfidf_preds = tfidf_model.predict(df_selected['reprocessed_content'])

# ==============================================================================
# 4. Soft Voting Ensemble (TF-IDF)
# ==============================================================================
with open('../models/tfidf_vectorizer_ensamble.pkl', 'rb') as f:
    ensemble_vectorizer = pickle.load(f)

with open('../models/soft_voting_ensamble_model_tfidf.pkl', 'rb') as f:
    ensemble_model = pickle.load(f)

X_ensemble = ensemble_vectorizer.transform(df_selected['reprocessed_content'])
ensemble_preds = ensemble_model.predict(X_ensemble)

# ==============================================================================
# Tampilkan hasil prediksi
# ==============================================================================
result = df_selected.copy()
result['bilstm_pred'] = bilstm_labels
result['count_logreg_pred'] = count_preds
result['tfidf_logreg_pred'] = tfidf_preds
result['ensemble_pred'] = ensemble_preds

# Mapping nilai
replace_map = {0: 'negative', 1: 'neutral', 2: 'positive'}
cols_to_replace = ['bilstm_pred', 'count_logreg_pred', 'tfidf_logreg_pred', 'ensemble_pred']
result[cols_to_replace] = result[cols_to_replace].replace(replace_map).astype('category')

result
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
#                                  reprocessed_content bilstm_pred  \
# 0  Gara aplikasi ini WhatsApp gw gk bsa di buka 😡...     neutral
# 1                                   Terimakasih.....     neutral
# 2                                       sangat cocok     neutral
# 3  jujur saya kecewa dg apk ini,bagian alamat tdk...     neutral
# 4  Sangat kecewa dengan sistem Tokopedia order ba...     neutral
#
#   count_logreg_pred tfidf_logreg_pred ensemble_pred
# 0          negative          negative      negative
# 1          positive          positive      positive
# 2          negative          negative      negative
# 3          negative          negative      negative
# 4          negative          negative      negative

# %% [markdown]
# # Interpretasi Hasil Prediksi Sentimen
#
# ## Analisis Baris per Baris
#
# ### Baris 0
# **Teks:** "Gara aplikasi ini WhatsApp gw gk bsa di buka 😡..."
# - BILSTM memprediksi: **neutral**
# - Model lain memprediksi: **negative**
# - **Interpretasi:** Kalimat ini jelas berisi keluhan/emosi negatif (ada emoji marah 😡), sehingga prediksi **negative** lebih tepat. Model BILSTM kurang sensitif terhadap nada negatif di kalimat ini.
#
# ### Baris 1
# **Teks:** "Terimakasih....."
# - BILSTM: **neutral**
# - Model lain: **positive**
# - **Interpretasi:** Kalimat mengandung ucapan terima kasih, yang bernada positif. Prediksi model count_logreg, tfidf_logreg, dan ensemble sudah benar. Prediksi BILSTM cenderung netral.
#
# ### Baris 2
# **Teks:** "sangat cocok"
# - Semua model selain BILSTM memprediksi: **negative**
# - BILSTM: **neutral**
# - **Interpretasi:** Kalimat ini jelas bernada positif (frasa “sangat cocok”). Semua model gagal mengenali ini, bahkan memprediksi negatif atau netral. Ini indikasi model perlu perbaikan khusus pada data positif pendek.
#
# ### Baris 3
# **Teks:** "jujur saya kecewa dg apk ini,bagian alamat tdk..."
# - Semua model selain BILSTM memprediksi: **negative**
# - BILSTM: **neutral**
# - **Interpretasi:** Kalimat berisi kata “kecewa”, jelas negatif.
#
# ### Baris 4
# **Teks:** "Sangat kecewa dengan sistem Tokopedia order ba..."
# - Semua model selain BILSTM memprediksi: **negative**
# - BILSTM: **neutral**
# - **Interpretasi:** Sama seperti baris 3, kalimat jelas negatif.
#
# ---
#
# ## Kesimpulan
#
# - Model BILSTM cenderung memprediksi label **neutral** untuk semua kalimat yang ada, kurang sensitif terhadap sentimen positif maupun negatif di contoh ini.
# - Model `count_logreg`, `tfidf_logreg`, dan `ensemble` lebih sering memprediksi dengan benar, kecuali kalimat sangat pendek dan positif (“sangat cocok”) yang mereka salah prediksi sebagai negatif.
# - Ada kecenderungan model klasik dan ensemble salah mendeteksi kalimat positif pendek sebagai negatif, menandakan perlunya data pelatihan tambahan atau tuning.
#
# ---
#
# ## Rekomendasi Perbaikan
#
# - Tambahkan contoh kalimat pendek dan bernada positif ke dataset pelatihan.
# - Evaluasi ulang model BILSTM agar tidak terlalu bias ke kelas netral.
# - Gunakan teknik augmentasi data untuk memperbaiki kesimbangan kelas.
# - Gunakan metrik evaluasi lengkap (precision, recall, F1-score per kelas) untuk analisis performa yang lebih mendalam.
#
# ---
